# %% [markdown]
# ![ggg.png](attachment:ggg.png)

# %% [markdown]
# ![vvvv.png](attachment:vvvv.png)

# %%
from recommender_functions import *Stranger in a Strange Land by Robert A Heinlein

# %%
main()
# Out:
# How would you like to search for a book?
# 1. By Title
# 2. By Author
# 3. By Genre
# Enter your choice (1, 2, or 3): 2
# Enter the author's name: Robert A. Heinlein
# Robert A. Heinlein's books are in the Best of 2023.
# Recommendation: stranger in a strange land by Robert A. Heinlein
# <img src="http://books.google.com/books/content?id=ZQhiPwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"/>
# Do you want to know more about 'stranger in a strange land'? (yes/no): yes
# "Stranger in a Strange Land" is a science fiction novel written by Robert A. Heinlein and published in 1961. The story follows Valentine Michael Smith, a human raised by Martians on Mars, who returns to Earth as an adult. As a stranger to human customs and culture, he struggles to understand and adapt to life on Earth.
#
# Smith possesses extraordinary abilities, including telepathy and the power to manipulate matter. He becomes a celebrity, attracting both fascination and fear from the public.
# ...

# %% [markdown]
# ## <font color='purple'>You might be interested in these genres</font>
#
# ![fffffffffffff.png](attachment:fffffffffffff.png)

# %% [markdown]
# ![p.png](attachment:p.png)

# %%
data_book=pd.read_csv("data_book.csv")
New_df=pd.read_csv("New_df.csv")

# %%
data_book['original_title'].value_counts().index
# Out:
# Index(['the hitchhiker's guide to the galaxy ', 'the alchemist',
#        'to kill a mockingbird', 'a court of mist and fury ', 'fahrenheit 451',
#        'the fellowship of the ring ', 'seabiscuit: an american legend',
#        'where she went ', 'the memory keeper's daughter', 'oedipus rex  ',
#        ...
#        'legend ', 'fried green tomatoes at the whistle stop cafe ',
#        'the complete maus', 'the hound of the baskervilles ',
#        'sophie's choice', 'hamlet', 'fifty shades darker ',
#        'the prince of tides', 'a court of thorns and roses ', 'the collector'],
#       dtype='object', length=994)

# %%
data_book['authors'].value_counts().index
# Out:
# Index(['Stephen King', 'William Shakespeare', 'Sarah J. Maas', 'Rick Riordan',
#        'Cassandra Clare', 'C.S. Lewis', 'J.K. Rowling', 'Nicholas Sparks',
#        'Charlaine Harris', 'Richelle Mead',
#        ...
#        'Daniel Defoe', 'Michael Chabon', 'Lao Tzu', 'John Knowles',
#        'Kami Garcia', 'David Mitchell', 'Beatrice Sparks', 'Charles Frazier',
#        'Dave Pelzer', 'Hubert Selby Jr.'],
#       dtype='object', length=590)

# %%
New_df['original_title'].value_counts().index
# Out:
# Index(['the gift', ' ', 'twilight', 'perfect', 'gone', 'the awakening',
#        'selected poems', 'avatar: the last airbender ', 'defiance', 'hidden',
#        ...
#        'book of a thousand days', 'mythology',
#        'the fabric of the cosmos: space, time and the texture of reality',
#        'killing yourself to live: 85% of a true story', 'hocus pocus',
#        'house of chains', 'oz: the wonderful wizard of oz', 'opposition',
#        'incubus dreams ', 'the first world war'],
#       dtype='object', length=9794)

# %%
New_df['authors'].value_counts().index
# Out:
# Index(['Stephen King', 'Nora Roberts', 'Dean Koontz', 'Terry Pratchett',
#        'Agatha Christie', 'Meg Cabot', 'James Patterson', 'John Grisham',
#        'J.D. Robb', 'David Baldacci',
#        ...
#        'Per Petterson, Anne Born',
#        'Doug Moench, Chuck Dixon, Jim Aparo, Norm Breyfogle, Graham Nolan, Jim Balent',
#        'Stephen King, Willem Dafoe', 'John Fante, Charles Bukowski',
#        'Rick Bragg', 'Philip Pullman, Jacob Grimm, Wilhelm Grimm',
#        'Stephen Coonts', 'Joss Whedon, Brett Matthews, Will Conrad',
#        'T.C. Boyle', 'John Keegan'],
#       dtype='object', length=4579)

# %%
official_genres = {"art", "biography", "business", "chick-lit", "christian", "classics",
          "comics", "contemporary", "cookbooks", "crime", "books", "fantasy", "fiction",
          "gay-and-lesbian", "graphic-novels", "historical-fiction", "history", "horror",
          "humor-and-comedy", "manga", "memoir", "music", "mystery", "nonfiction", "paranormal",
          "philosophy", "poetry", "psychology", "religion", "romance", "science", "science-fiction", 
          "self-help", "suspense", "spirituality", "sports", "thriller", "travel", "young-adult"}
